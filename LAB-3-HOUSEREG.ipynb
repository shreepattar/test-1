# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\CSE-LAB-301\Desktop\aiml\AIML_Lab_Dataset\pgm3\housing_prices.csv")

# %%
data.head()
# Out:
#    AREA  FLOOR  ROOM CODE  PRICE
# 0  1000      7     2    B   5618
# 1  1030      7     1    A   5201
# 2  1060      1     1    A   4779
# 3  1090      6     1    A   5425
# 4  1120      0     2    B   5657

# %%
def func(r):
    if r == 'A':
        return 0
    else:
        return 1

# %%
data['CODE']=data['CODE'].apply(func)

# %%
data
# Out:
#     AREA  FLOOR  ROOM  CODE  PRICE
# 0   1000      7     2     1   5618
# 1   1030      7     1     0   5201
# 2   1060      1     1     0   4779
# 3   1090      6     1     0   5425
# 4   1120      0     2     1   5657
# 5   1150      1     1     1   4945
# 6   1180      6     2     1   6475
# 7   1210      0     1     0   5352
# 8   1240      0     2     1   6290
# 9   1270      7     1     0   6147
# 10  1300     10     2     0   7718
# 11  1330      3     2     1   7035
# 12  1360      3     3     1   8712
# 13  1390      8     3     1   9457
# 14  1420      3     2     0   7304
# 15  1450      7     2     1   7535
# 16  1480      8     3     1   9968
# 17  1510      7     2     0   7614
# 18  1540      6     3     0   9762
# 19  1570      8     3     0  10067
# 20  1600      6     2     0   8074
# 21  1630      4     3     1  10201
# 22  1660      1     3     1  10051
# 23  1690      3     3     1   9775
# 24  1720      3     3     0  10229
# 25  1750      0     2     0   8314
# ...

# %%
X=data.drop(columns=['PRICE'])
y=data['PRICE']

# %%
y
# Out:
# 0      5618
# 1      5201
# 2      4779
# 3      5425
# 4      5657
# 5      4945
# 6      6475
# 7      5352
# 8      6290
# 9      6147
# 10     7718
# 11     7035
# 12     8712
# 13     9457
# 14     7304
# 15     7535
# 16     9968
# 17     7614
# 18     9762
# 19    10067
# 20     8074
# 21    10201
# 22    10051
# 23     9775
# 24    10229
# 25     8314
# 26     9288
# 27    10503
# 28     9763
# 29    11527
# 30     9912
# 31    10204
# 32     9085
# 33    10240
# 34    15220
# 35    12278
# 36    22270
# 37    12574
# 38    12618
# 39    15457
# 40    12793
# 41    12641
# 42    17207
# 43    16969
# 44    16293
# 45    16845
# 46    17604
# 47    17310
# 48    14036
# 49    13699
# Name: PRICE, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model=LinearRegression(fit_intercept=True)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,mean_squared_error,mean_absolute_error

# %%
print(mean_squared_error(y_test,ypred))
# Out:
# 555058.701013454

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(accuracy_score(y_test,ypred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
# ...

# %%
print(mean_absolute_error(y_test,ypred))
# Out:
# 581.471108650223

# %%
import seaborn as sns

# %%
sns.pairplot(data)
# Out:
# C:\Users\CSE-LAB-301\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=data,x='AREA',y='FLOOR',hue='CODE')
# Out:
# C:\Users\CSE-LAB-301\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(data=data)
# Out:
# <Axes: ylabel='count'>

# %%
sns.heatmap(data=data)
# Out:
# <Axes: >

# %%
sns.jointplot(data=data,x='AREA',y='FLOOR',kind="hex", color="#4CB391",xlim=10000,ylim=50)
